# %%
import pandas as pd
from google.colab import files
Data = files.upload()
# Out:
#      <input type="file" id="files-f611d126-0d5b-4372-80a3-8d3da10daed6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f611d126-0d5b-4372-80a3-8d3da10daed6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#reading zomato.csv file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

df=pd.read_csv('zomato.csv')
df.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate votes                           phone  \
# 0          Yes        Yes  4.1/5   775    080 42297555\n+91 9743772233
# 1          Yes         No  4.1/5   787                    080 41714161
# 2          Yes         No  3.8/5   918                  +91 9663487993
# 3           No         No  3.7/5    88                  +91 9620009302
# 4           No         No  3.8/5   166  +91 8026612447\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# ...

# %%
#Data Cleaning
df=df.drop_duplicates()
df['rate']=df['rate'].astype(str).str.replace('/5','',regex=False)
df['rate']=pd.to_numeric(df['rate'],errors='coerce')
cost_col='approx_cost(for two people)'
if cost_col in df.columns:
    df[cost_col]=df[cost_col].astype(str).str.replace(',','',regex=False)
    df[cost_col]=pd.to_numeric(df[cost_col],errors='coerce')
df=df.fillna({'cuisines':'Unknown','location':'Unknown'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39654 entries, 0 to 56251
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      39652 non-null  object
#  1   name                         39653 non-null  object
#  2   online_order                 39650 non-null  object
#  3   book_table                   39616 non-null  object
#  4   rate                         30238 non-null  float64
#  5   votes                        39596 non-null  object
#  6   phone                        38846 non-null  object
#  7   location                     39654 non-null  object
#  8   rest_type                    39406 non-null  object
#  9   dish_liked                   21974 non-null  object
#  10  cuisines                     39654 non-null  object
#  11  approx_cost(for two people)  35288 non-null  float64
#  12  listed_in(type)              36778 non-null  object
# ...

# %%
#EDA and Visualizations
top=df['cuisines'].value_counts().head(10)
top.plot(kind='bar')
plt.show()

loc=df['location'].value_counts().head(10)
loc.plot(kind='bar')
plt.show()

if cost_col in df.columns:
    plt.scatter(df[cost_col],df['rate'],alpha=0.3)
    plt.xlabel('Cost')
    plt.ylabel('Rating')
    plt.show()

num=df.select_dtypes(include='number')
sns.heatmap(num.corr(),annot=True,cmap='coolwarm')
plt.show()

text=' '.join(df['cuisines'].dropna().astype(str))
wc=WordCloud(width=800,height=400,background_color='white').generate(text)
plt.imshow(wc);plt.axis('off');plt.show()

# %%
#Recommendations
1.partner with top-rated restaurants.
2.Recommend cuisine-wise.
3.Promote affordable high-rated restaurants.
4.Encourage online ordering or table booking.
5.Target marketing using hotspot locations.
